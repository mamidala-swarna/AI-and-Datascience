# %%
print(10)
print(10.5)
print(-5)
# Out:
# 10
# 10.5
# -5

# %%
print('two')
print("three")
# Out:
# two
# three

# %%
today="parents anniversary"
print(today)
# Out:
# parents anniversary

# %%
day2moro="monday"
print(day2moro)
# Out:
# monday

# %%
_2day="saturday"
print(_2day)
# Out:
# saturday

# %%
student_name="swarna"
students_age=21
student_gpa=8.0

# %%
pi=3.14159265359 #not recommended
print(pi)
# Out:
# 3.14159265359

# %%
PI=3.14159265359 #recommended for static values
print(PI)
# Out:
# 3.14159265359

# %%
STUDENT_ADHAAR_ID=1234567890123
print(STUDENT_ADHAAR_ID)
# Out:
# 1234567890123

# %%
student_name="swarna"
student_age=21
student_gpa=8.0
student_passed=True
STUDENT_ADHAAR_ID=None

# %%
print(student_name)
print(student_age)
print(student_gpa)
print(student_passed)
print(STUDENT_ADHAAR_ID)
# Out:
# swarna
# 21
# 8.0
# True
# None

# %%
print("Student Name: " + student_name)
print("Student Age: ", student_age)
print("Student GPA: ", student_gpa)
print("Student Passed: ", student_passed)
print("Student AADHAR ID: ", STUDENT_ADHAAR_ID)
# Out:
# Student Name: swarna
# Student Age:  21
# Student GPA:  8.0
# Student Passed:  True
# Student AADHAR ID:  None

# %%
type(student_name) #type()
print(type(student_name))
print(type(student_age))
print(type(student_gpa))
print(type(student_passed))
print(type(STUDENT_ADHAAR_ID))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
id(student_name) #memory address of a variable
print(id(student_name))
print(id(student_age))
print(id(student_gpa))
print(id(student_passed))
print(id(STUDENT_ADHAAR_ID))
# Out:
# 2050551061296
# 140720753526520
# 2050550636464
# 140720752626432
# 140720752626496

# %%
value_X = 10 #python memory model
print(id(value_X))

value_Y = 100
print(id(value_Y))

value_Z = 10
print(id(value_Z))
# Out:
# 140720753526168
# 140720753529048
# 140720753526168
