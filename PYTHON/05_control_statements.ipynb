# %%
#Identation
print("Hello")
 #print("python")#IndentationError: unexpected indent
#->Indentation refers to code Structuring and code blocks
# Out:
# Hello

# %%
#in python ,if statement is used to execute a block of code
#only when a specific condition evaluates to True
#if True: 
#print("This")#IndentationError: expected an indented block after 'if' statement on line 3
#print("is")
#print("the")
#print("block")
#print("of ")
#print("code")
#print("execute")

# %%
#Consistent blocks
if True:
 print("This")
 print("is")
 print("the")
 print("block")
 print("of ")
 print("code")
 print("to")
 print("execute")
# Out:
# This
# is
# the
# block
# of
# code
# to
# execute

# %%
#Inonsistent blocks
#if True:
 #print("This")
  #print("is")
#print("the")
   #print("block")
    #print("of ")
  #print("code")
  #print("to")
 #print("execute")

# %%
if True:
            print("This") #not Recommended
            print("is")
            print("the")
            print("block")
# Out:
# This
# is
# the
# block

# %%
if True:
    print("This")
    print("is")
    print("the")
    print("block")
    print("of ")
    print("code")
    print("to")
    print("execute")
# Out:
# This
# is
# the
# block
# of
# code
# to
# execute

# %%
#if condition
if 5>2:
    print("yes 5>2 is correct")
if 5<2:
    print("yes 5>2 is correct")
    
num=-10
if num>0:
    print("Given Number is Positive")
if num<0:
    print("Given Number is Negative")
# Out:
# yes 5>2 is correct
# Given Number is Negative

# %%
#if else conditon
num=10
if num>0:
    print("Given Number is Positive")
else:
    print("Given Number is Negative")
# Out:
# Given Number is Positive

# %%
#without input() - input is hardcoded
name="Swarna"
print(name)
# Out:
# Swarna

# %%
#input(): reads the input from user and store the value of string
name=input("Enter Your Name: ")
print(name)
# Out:
# Enter Your Name:  swarna
# swarna

# %%
num=input("Enter Number: ")
num=int(num)
if num>0:#'>' not supported between instances of 'str' and 'int'
    print("Given Number is Positive")
else:
    print("Given Number is Negative")
# Out:
# Enter Number:  51
# Given Number is Positive

# %%
#Read Some Name
name=input("Enter Your Name")
print(name)
print("Welcome: "+name)#Concatenation
print("Welcome: ",name)#comma operator
print("Welcom{name}")#No Interpolation
print(f"Welcome {name}")#With Interpolation
# Out:
# Enter Your Name swarna
# swarna
# Welcome: swarna
# Welcome:  swarna
# Welcom{name}
# Welcome swarna

# %%
num=input("Enter Number: ")
num=int(num)
if num>0:#'>' not supported between instances of 'str' and 'int'
    print(f"Given Number {num} is Positive")
else:
    print(f"Given Number {num} is Negative")
# Out:
# Enter Number:  33
# Given Number 33 is Positive

# %%
#Voting App
name=input("Enter Your name:")
age=int(input("Enter Your Age:"))

if age >= 18:
    print(f"{name} You can vote" )
else:
    print(f"{name} You cannot vote as you are still {age} years only")
# Out:
# Enter Your name: kitty
# Enter Your Age: 11
# kitty You cannot vote as you are still 11 years only

# %%
#Conditional Expression
age=int(input("enter your age: "))
#value_if_true if condition else value_if_false
status="You can vote" if age >= 18 else"You cannot vote"
print(status)
# Out:
# enter your age:  21
# You can vote

# %%
### Multiple checks to be done
#check for grades according to marks
marks=int(input("Enter Your Marks: "))
if marks>=90:
    print("A Grade")
elif marks>=75:
    print("B Grade")
elif marks>=60:
    print("C Grade")
elif marks>=50:
    print("D Grade")
elif marks>=35:
    print("E Grade")
else:
    print("Failed")
# Out:
# Enter Your Marks:  86
# B Grade

# %%
#match case
choices="1- Burger > 2-Pizza > 3-Pasta >4-Biryani"
print(choices)
food_item=int(input("Enter Your Choice: "))
match food_item:
    case 1:
        print("Ordered Burger")
    case 2:
        print("Ordered Pizza")
    case 3:
        print("Ordered Pasta")
    case 4:
        print("Ordered Biryani")
    case _:
        print("Invalid Choice")
# Out:
# 1- Burger > 2-Pizza > 3-Pasta >4-Biryani
# Enter Your Choice:  2
# Ordered Pizza

# %%
atm_menu="1 - Deposit Amount > 2 - Withdraw Amount > 3 - Check Balance > 4 - Remove Card"
print(atm_menu)
user_choice=int(input("Enter your choice"))
match user_choice:
    case 1:
        print("Deposited Amount")
    case 2:
        print("Withdraw Amount")
    case 3:
        print("Check Balance")
    case 4:
        print("Remove Card")
    case _:
        print("Invalid Choice")
# Out:
# 1 - Deposit Amount > 2 - Withdraw Amount > 3 - Check Balance > 4 - Remove Card
# Enter your choice 0
# Invalid Choice
