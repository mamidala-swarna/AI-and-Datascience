# %%
#Dictionaries
#empty dictionary
empty_dictionary={}
print(empty_dictionary)
print(type(empty_dictionary))
# Out:
# {}
# <class 'dict'>

# %%
empty_dictionary = dict()
print(empty_dictionary)
print(type(empty_dictionary))
# Out:
# {}
# <class 'dict'>

# %%
#Dictionary with numeric data
data={1:10,2:20,3:30,4:40,5:50}
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50}

# %%
#Dictionary with text data
data={"c1":"python","c2":"ai","c3":"cloud"}
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'c1': 'python', 'c2': 'ai', 'c3': 'cloud'}

# %%
#Dictionary with mixed data
data={1:10,2:30,3:30,"c1":"python","c2":"ai","gpa":8.5,"passed":True}
print(data)
print(type(data))
# Out:
# {1: 10, 2: 30, 3: 30, 'c1': 'python', 'c2': 'ai', 'gpa': 8.5, 'passed': True}
# <class 'dict'>

# %%
#Access data in dictionary
data = {1:10,2:20,3:30,4:40,5:50}
print(data)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50}

# %%
#First element
#data = {1:10,2:20,3:30,4:40,5:50}
#first_element=data[0]#KeyError: 0
#print("First Element",first_element)

# last_element = data[-1]
# print("Last Element",last_element)

# %%
data = {1:10,2:20,3:30,4:40,5:50}
first_element = data[1] # NOTE: This is Key, not index
print("First Element",first_element)

last_element = data[5]
print("Last Element",last_element)

# unknown_element = data[10] # # KeyError: 10
# # print(unknown_element)
# Out:
# First Element 10
# Last Element 50

# %%
# Access Individual Elements 
data = {1:10,2:20,3:30,4:40,5:50}
print(data[1])
print(data[2])
print(data[3])
print(data[4])
print(data[5])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# Access Individual Elements  -> 10k elements 
data = [10,20,30,40,50,1000000]
data = {1:10,2:20,3:30,4:40,5:50,10000:1000000}
print(data[1])
print(data[2])
print(data[3])
print(data[4])
# print(data[9999999])
# Out:
# 10
# 20
# 30
# 40

# %%
#Access Individual elements ->10k elements
data = {1:10,2:20,3:30,4:40,5:50,10000:1000000}
#print(dir(data)) #__iter__
for num in data: #only keys we got
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 10000

# %%
for key in data: #only keys we got
    print(key)
# Out:
# 1
# 2
# 3
# 4
# 5
# 10000

# %%
for key in data:
    print(data[key])
# Out:
# 10
# 20
# 30
# 40
# 50
# 1000000

# %%
data = {1:10,2:20,3:30,4:40,5:50}
for key in data:
    print(key*10)

data = {1:10,2:20,3:30,4:40,5:50}
for key in data:
    print(data[key]*10)
# Out:
# 10
# 20
# 30
# 40
# 50
# 100
# 200
# 300
# 400
# 500

# %%
#Apply Operators->Requirement:Give Courses in upper case
data = {"c1":"python","c2":"ai","c3":"cloud"}
print(data)
for course in data:
    print(data[course].upper())
# Out:
# {'c1': 'python', 'c2': 'ai', 'c3': 'cloud'}
# PYTHON
# AI
# CLOUD

# %%
# Apply Conditionals -> Requirement: Give Only Even Numbers 
data = {1:10,2:20,3:35,4:45,5:50}
for key in data:
    if data[key]%2==0:
        print(data[key])
# Out:
# 10
# 20
# 50

# %%
#Duplicates Allowed - Values Can be Duplicated & Order preserved
data = {1:10,2:20,3:30,4:40,5:50,6:20,7:10,8:20,9:20}
print(data)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 20, 7: 10, 8: 20, 9: 20}

# %%
#Duplicates ALLOwed - Keys should be Unique,Latest key will override Old key
data={1:10,2:20,3:30,1:40,5:20,2:60}
print(data)
# Out:
# {1: 40, 2: 60, 3: 30, 5: 20}

# %%
# Keys must be immutable objects only
data = {1:10,2:20}
print(data)

# Keys must be immutable objects only
#data = {[1]:10,[2]:20}
#print(data)

# Keys must be immutable objects only, but values can be any object 
data = {1:[10],2:[20]}
print(data)
# Out:
# {1: 10, 2: 20}
# {1: [10], 2: [20]}

# %%
# Keys must be immutable objects only
data = {(1):[10],(2):[20]}
print(data)
# Out:
# {1: [10], 2: [20]}

# %%
# Keys must be immutable objects only
data = {"1":10,"2":20}
print(data)
# Out:
# {'1': 10, '2': 20}

# %%
#Immutability Check
data={1:10,2:20}
print(data)
data[1]=100
print(data)
# Out:
# {1: 10, 2: 20}
# {1: 100, 2: 20}

# %%
#Real world dictionaries looks like Json data
students={"101":{},"102":{}}
print(students)
print(type(students))
# Out:
# {'101': {}, '102': {}}
# <class 'dict'>

# %%
students={
    "101":{
        "name":"Vighnesh",
        "email":"vighnesh@gmail.com",
        "courses":["ML","DL","AgenticAI"],
        "courses_fee":(10000,20000,30000)
    },

    "102":{
        "name":"Swarna",
        "email":"swarna@gmail.com",
        "courses":["Python","ML","DL"],
        "courses_fee":(8000,10000,20000)
    }
}
print(students)
print(type(students))
# Out:
# {'101': {'name': 'Vighnesh', 'email': 'vighnesh@gmail.com', 'courses': ['ML', 'DL', 'AgenticAI'], 'courses_fee': (10000, 20000, 30000)}, '102': {'name': 'Swarna', 'email': 'swarna@gmail.com', 'courses': ['Python', 'ML', 'DL'], 'courses_fee': (8000, 10000, 20000)}}
# <class 'dict'>

# %%
#Get ALL students details
print(students)
# Out:
# {'101': {'name': 'Vighnesh', 'email': 'vighnesh@gmail.com', 'courses': ['ML', 'DL', 'AgenticAI'], 'courses_fee': (10000, 20000, 30000)}, '102': {'name': 'Swarna', 'email': 'swarna@gmail.com', 'courses': ['Python', 'ML', 'DL'], 'courses_fee': (8000, 10000, 20000)}}

# %%
# Get 101 Student Details 
# print(students[101]) # KeyError: 101, as its int
print(students["101"])

# Get 102 Student Details 
# print(students[101]) # KeyError: 101, as its int
print(students["102"])
# Out:
# {'name': 'Vighnesh', 'email': 'vighnesh@gmail.com', 'courses': ['ML', 'DL', 'AgenticAI'], 'courses_fee': (10000, 20000, 30000)}
# {'name': 'Swarna', 'email': 'swarna@gmail.com', 'courses': ['Python', 'ML', 'DL'], 'courses_fee': (8000, 10000, 20000)}

# %%
#Get Courses enrolled by swarna
print(students["102"]["courses"])
#Get 2nd course enrolled by swarna
print("2nd course:",students["102"]["courses"][1])
# Out:
# ['Python', 'ML', 'DL']
# 2nd course: ML

# %%
#Check if mike is google customer or not
if students["102"]["email"].endswith("@gmail.com"):
    print(f"User {students["102"]['name']} is Google Customer")
else:
     print(f"User {students["102"]['name']} is not a Google Customer")
# Out:
# User Swarna is Google Customer

# %%
students["102"]["email"]="swarna@outlook.com"
print(students["102"])
# Out:
# {'name': 'Swarna', 'email': 'swarna@outlook.com', 'courses': ['Python', 'ML', 'DL'], 'courses_fee': (8000, 10000, 20000)}

# %%
#Dictionary operations
print(dir(students))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# ### Dictionary Methods ###

# %%
#Dictionary Methods/Operations
data={"a":"apple","b":"banana"}
print(data)
# Out:
# {'a': 'apple', 'b': 'banana'}

# %%
#update():adds/updates items in dictionary
data.update({"c":"cherry"}) #adds item if key is not present
print(data)
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry'}

# %%
data.update({"a":"apricot"})#updates item if key is present
print(data)
# Out:
# {'a': 'apricot', 'b': 'banana', 'c': 'cherry'}

# %%
#pop():Removes an item by key
data={"a":"apple","b":"banana"}
print(data)
data.pop("a")
print(data)
#data.pop("c")#Keyerror:'c'
#print(data)
# Out:
# {'a': 'apple', 'b': 'banana'}
# {'b': 'banana'}

# %%
#popitem(): Removes last item
data={"a":"apple","b":"banana"}
print(data)
data.popitem()
print(data)
# Out:
# {'a': 'apple', 'b': 'banana'}
# {'a': 'apple'}

# %%
#clear():empties dictionary
data={"a":"apple","b":"banana"}
print(data)
data.clear()
print(data)
# Out:
# {'a': 'apple', 'b': 'banana'}
# {}

# %%
#get():used to get value by key
data={"a":"apple","b":"banana"}
print(data)
data.get("a")
print(data.get("a"))
print(data.get("c"))
# Out:
# {'a': 'apple', 'b': 'banana'}
# apple
# None

# %%
#keys():used to get keys
data={"a":"apple","b":"banana"}
print(data)
data.keys()
print(data.keys())

for key in data.keys():
    print(key)
# Out:
# {'a': 'apple', 'b': 'banana'}
# dict_keys(['a', 'b'])
# a
# b

# %%
#values():Used to get values
data={"a":"apple","b":"banana"}
print(data)
data.values()
print(data.values())

for value in data.values():
    print(value)
# Out:
# {'a': 'apple', 'b': 'banana'}
# dict_values(['apple', 'banana'])
# apple
# banana

# %%
#items():Used to get keys and values
data={"a":"apple","b":"banana"}
print(data)
data.items()
print(data.items())
for item in data.items():
    print(item)
# Out:
# {'a': 'apple', 'b': 'banana'}
# dict_items([('a', 'apple'), ('b', 'banana')])
# ('a', 'apple')
# ('b', 'banana')

# %%
#setdefault():Returns a value of key,if the key is present
#If key is not present,then adds the item and returns the value
data = {"a":"apple","b":"banana"}
print(data)
data.setdefault("b","blueberry")
print(data.setdefault("b","blueberry"))
# Out:
# {'a': 'apple', 'b': 'banana'}
# banana

# %%
data = {"a":"apple","b":"banana"}
print(data)
print(data.setdefault("c","cherry"))
print(data)
# Out:
# {'a': 'apple', 'b': 'banana'}
# cherry
# {'a': 'apple', 'b': 'banana', 'c': 'cherry'}

# %%
#copy();creates a copy
data={"a":"apple","b":"banana"}
print(data)
backup=data.copy()
print(backup)
# Out:
# {'a': 'apple', 'b': 'banana'}
# {'a': 'apple', 'b': 'banana'}
